# %%
using Plots
plotly()

plot(
    heatmap(rand(5, 5)),
    surface(rand(5, 5), cbar = false),
    wireframe(rand(5, 5)),
    bar(rand(5)),
)

# %%
for x in 1:100
          p = plot(f(x),g(y))
          display(p)
          sleep(1)
 end
# Out:
# UndefVarError: f not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ .\In[8]:2
#  [2] eval
#    @ .\boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1196
